# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("terverlab.csv", decimal=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   человек      50 non-null     int64
#  1   тыс. руб.    50 non-null     float64
#  2   тыс. руб..1  50 non-null     float64
#  3   тыс. руб..2  50 non-null     float64
#  4   тыс. руб..3  50 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 2.1 KB

# %%
df.columns.values
# Out:
# array(['человек', 'тыс. руб.', 'тыс. руб..1', 'тыс. руб..2',
#        'тыс. руб..3'], dtype=object)

# %%
for i in df.columns.values:
  print("column: ", i)
  print("Среднее: ", np.mean(df[i]))
  print("Медиана: ", np.median(df[i]))
  print("Дисперсия: ", np.var(df[i], ddof=1))
  print('Среднеквадратическое отклонение', np.std(df[i], ddof=1))
  print('Коэффициент асимметрии', stats.skew(df[i]))
  print('Коэффициент эксцесса', stats.kurtosis(df[i]))
  print('Коэффициент вариации', (np.std(df[i], ddof=1) / np.mean(df[i])) * 100 if np.mean(df[i]) != 0 else np.nan)
# Out:
# column:  человек
# Среднее:  832.78
# Медиана:  852.0
# Дисперсия:  283738.5832653061
# Среднеквадратическое отклонение 532.6711774306041
# Коэффициент асимметрии 0.9419801623226514
# Коэффициент эксцесса 0.5558381491440327
# Коэффициент вариации 63.96301273212662
# column:  тыс. руб.
# Среднее:  25.962
# Медиана:  24.25
# Дисперсия:  128.09546530612246
# Среднеквадратическое отклонение 11.317926722952507
# Коэффициент асимметрии 0.9195968923938466
# Коэффициент эксцесса 1.0263598695363791
# Коэффициент вариации 43.59420199889264
# column:  тыс. руб..1
# Среднее:  7.03
# Медиана:  6.95
# Дисперсия:  3.1845918367346937
# Среднеквадратическое отклонение 1.784542472662025
# Коэффициент асимметрии 0.08302530327719526
# Коэффициент эксцесса -0.021223817579838045
# Коэффициент вариации 25.38467244184957
# column:  тыс. руб..2
# Среднее:  7.299999999999999
# Медиана:  7.3
# Дисперсия:  4.1420408163265305
# Среднеквадратическое отклонение 2.035200436400929
# Коэффициент асимметрии 0.5397043410619835
# Коэффициент эксцесса -0.23989469062447988
# Коэффициент вариации 27.879458032889442
# column:  тыс. руб..3
# Среднее:  14.2
# Медиана:  13.45
# Дисперсия:  21.9338775510204
# Среднеквадратическое отклонение 4.683361778788865
# Коэффициент асимметрии 0.580219861042523
# Коэффициент эксцесса -0.12464888215763503
# Коэффициент вариации 32.98142097738638

# %%
for i in df.columns.values:
  print(max(df[i]), min(df[i]))
# Out:
# 2342 205
# 60.1 4.7
# 10.9 3.3
# 12.4 3.7
# 25.5 6.7

# %%
k = int(1 + 3.332*np.log10(len(df)))
k
# Out:
# 6

# %%
r = list(range(2*k))
s = 0
for i in range(200): 
  r[i] = s
  s+=0.5

# %%
plt.figure(figsize=(15,8))
plt.xlim(0, 50)
for i in df.columns.values:
  step = (max(df[i]) - min(df[i]))/k
  bins = [j * step for j in range(k + 1)]
  print("Ядро: ", end='')
  for j in range(0, len(bins) - 2, 2):
    print('[', bins[j], ', ', bins[j + 1], ')', end='')
  plt.hist(df[i], bins=bins, label=i,alpha=0.5, density=True)
  print()
plt.legend(fontsize=16)
# Out:
# Ядро: [ 0.0 ,  356.1666666666667 )[ 712.3333333333334 ,  1068.5 )[ 1424.6666666666667 ,  1780.8333333333335 )
# Ядро: [ 0.0 ,  9.233333333333333 )[ 18.466666666666665 ,  27.699999999999996 )[ 36.93333333333333 ,  46.166666666666664 )
# Ядро: [ 0.0 ,  1.2666666666666668 )[ 2.5333333333333337 ,  3.8000000000000007 )[ 5.066666666666667 ,  6.333333333333334 )
# Ядро: [ 0.0 ,  1.45 )[ 2.9 ,  4.35 )[ 5.8 ,  7.25 )
# Ядро: [ 0.0 ,  3.1333333333333333 )[ 6.266666666666667 ,  9.4 )[ 12.533333333333333 ,  15.666666666666666 )

# %%
df.plot(kind='kde', xlim=(0, 40))
# Out:
# <Axes: ylabel='Density'>
