# %% [markdown]
# # Лабораторная работа №1 ООП
# ## Графики симметричного гиперболического распределения с параметрами $\nu, \mu\space и \space \lambda$

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../dist.csv", sep=',')

# %%
dist1 = data['dist1']
dist2 = data['dist2']
mixture_dist = data['mixt']
empiric_dist = data['emp']

# %%
r = list(range(200))
s = -50
for i in range(200): 
  r[i] = s
  s+=0.5

# %% [markdown]
# ### График распределений при $\mu=0, \lambda=1$
# Размер выборки для каждого распределления = 10000
# - dist1 - основное распределение при $\nu=0.1$
# - dist2 - основное распределение при $\nu=30$
# - mixt - смесь распределений dist1 и dist2 при $p = 0.5$
# - emp - эмпирическое распределение построенное из 10000 случайных величин dist1

# %%
data.plot(xlim=(-10, 10), kind='kde', alpha=0.5)
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(15,8))
plt.xlim(-15, 15)
plt.hist(dist1, bins=r, label='dist1', color='blue', density=True)
plt.hist(dist2,bins=r, alpha=0.4, label='dist2', color='red', density=True)
plt.hist(mixture_dist, bins=r, alpha=0.4, label='mixture', color='orange', density=True)
plt.hist(empiric_dist, bins=r, alpha=0.6, label='empiric', color='green', density=True)
plt.legend(fontsize=16)

# %%
nudist = pd.read_csv("../nudist.csv", sep=',')

# %% [markdown]
# ###  Графики основного распределения при $\mu = 0, \lambda = 1$ и разных $\nu$
# Размер выборки: 10000

# %%
nudist.plot(kind='kde', xlim=(-10, 10), alpha=0.9)
# Out:
# <Axes: ylabel='Density'>

# %%
mudist = pd.read_csv('../mudist.csv', sep=',')
mudist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   -20     10000 non-null  float64
#  1   -18     10000 non-null  float64
#  2   -16     10000 non-null  float64
#  3   -14     10000 non-null  float64
#  4   -12     10000 non-null  float64
#  5   -10     10000 non-null  float64
#  6   -8      10000 non-null  float64
#  7   -6      10000 non-null  float64
#  8   -4      10000 non-null  float64
#  9   -2      10000 non-null  float64
#  10  0       10000 non-null  float64
#  11  2       10000 non-null  float64
#  12  4       10000 non-null  float64
#  13  6       10000 non-null  float64
#  14  8       10000 non-null  float64
#  15  10      10000 non-null  float64
#  16  12      10000 non-null  float64
#  17  14      10000 non-null  float64
#  18  16      10000 non-null  float64
#  19  18      10000 non-null  float64
# ...

# %% [markdown]
# ### График основного распределения при $\nu=1, \lambda = 1$ и $\mu\in[-20, 20]$ с шагом 2

# %%
mudist.plot(kind='kde', xlim=(-10, 10))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### График основного распределения при $\nu = 1, \mu = 0$ и $\lambda \in [0.1, 2]$ с шагом 0.1
# Вывод: при уменьшении масштаба плотность в центре возрастает

# %%
ladist = pd.read_csv("../ladist.csv", sep=',')
print(ladist.info())
ladist.plot(kind='kde', xlim=(-5, 5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.1     10000 non-null  float64
#  1   0.2     10000 non-null  float64
#  2   0.3     10000 non-null  float64
#  3   0.4     10000 non-null  float64
#  4   0.5     10000 non-null  float64
#  5   0.6     10000 non-null  float64
#  6   0.7     10000 non-null  float64
#  7   0.8     10000 non-null  float64
#  8   0.9     10000 non-null  float64
#  9   1       10000 non-null  float64
#  10  1.1     10000 non-null  float64
#  11  1.2     10000 non-null  float64
#  12  1.3     10000 non-null  float64
#  13  1.4     10000 non-null  float64
#  14  1.5     10000 non-null  float64
#  15  1.6     10000 non-null  float64
#  16  1.7     10000 non-null  float64
#  17  1.8     10000 non-null  float64
#  18  1.9     10000 non-null  float64
#  19  2       10000 non-null  float64
# dtypes: float64(20)
# ...

# %%
density = pd.read_csv("../densitydist.csv", sep=",")
print(density.info())
density.plot(x='x')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   x           10000 non-null  float64
#  1   dist1 f(x)  10000 non-null  float64
#  2   dist2 f(x)  10000 non-null  float64
#  3    mixt f(x)  10000 non-null  float64
#  4    emp f(x)   10000 non-null  float64
# dtypes: float64(5)
# memory usage: 390.8 KB
# None
# <Axes: xlabel='x'>

# %%
df = pd.read_csv("../test311.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
#plt.xlim(-10, 10)
plt.plot(df['x'], df['f(x)'], linewidth=2, label='Теоретическое основное распределение\nf(x) nu=1, lambda=1, mu=0', alpha=0.8)
plt.scatter(df['xi'], df['f(xi)'], color='red', label='Эмпирическое распределение f(xi)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.1.1', fontsize=16)
#plt.text(0.02, 0.98,'lambda=1', transform=plt.gca().transAxes, fontsize=12,
#         verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
plt.legend(fontsize=16)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   xi      61 non-null     float64
#  3   f(xi)   61 non-null     float64
# dtypes: float64(4)
# memory usage: 2.0 KB
# None

# %%
df = pd.read_csv("../test312.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
#plt.xlim(-10, 10)
plt.plot(df['x'], df['f(x)'], linewidth=2, label='Теоретическое основное распределение\nf(x) nu=1, lambda=2, mu=0', alpha=0.8)
plt.scatter(df['xi'], df['f(xi)'], color='red', label='Эмпирическое распределение f(xi)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.1.2', fontsize=16)
plt.legend(fontsize=16)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   xi      61 non-null     float64
#  3   f(xi)   61 non-null     float64
# dtypes: float64(4)
# memory usage: 2.0 KB
# None

# %%
df = pd.read_csv("../test313.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
#plt.xlim(-10, 10)
plt.plot(df['x'], df['f(x)'], linewidth=2, label='Теоретическое основное распределение\nf(x) nu=1, lambda=2, mu=10', alpha=0.8)
plt.scatter(df['xi'], df['f(xi)'], color='red', label='Эмпирическое распределение f(xi)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.1.3', fontsize=16)
plt.legend(fontsize=16)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   xi      61 non-null     float64
#  3   f(xi)   61 non-null     float64
# dtypes: float64(4)
# memory usage: 2.0 KB
# None

# %%
df = pd.read_csv("../test321.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
plt.plot(df['x'], df['f(x)'], linewidth=2,
         label='Теоретическое распределение смеси\nf(x) nu1=1, lambda1=2, mu1=10\nnu2=1, lambda2=2, mu2=10, p=0.5', alpha=0.8)
plt.scatter(df['xi'], df['f(xi)'], color='red', label='Эмпирическое распределение f(xi)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.2.1', fontsize=16)
plt.legend(fontsize=16)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   xi      61 non-null     float64
#  3   f(xi)   61 non-null     float64
# dtypes: float64(4)
# memory usage: 2.0 KB
# None

# %%
df = pd.read_csv("../test322.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
plt.plot(df['x'], df['f(x)'], linewidth=2,
         label='Теоретическое распределение смеси\nf(x) nu1=1, lambda1=1, mu1=0\nnu2=1, lambda2=1, mu2=2, p=0.75', alpha=0.8)
plt.scatter(df['xi'], df['f(xi)'], color='red', label='Эмпирическое распределение f(xi)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.2.2', fontsize=16)
plt.legend(fontsize=16)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   xi      61 non-null     float64
#  3   f(xi)   61 non-null     float64
# dtypes: float64(4)
# memory usage: 2.0 KB
# None

# %%
df = pd.read_csv("../test323.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
plt.plot(df['x'], df['f(x)'], linewidth=2,
         label='Теоретическое распределение смеси\nf(x) nu1=1, lambda1=1, mu1=0\nnu2=1, lambda2=3, mu2=0, p=0.5', alpha=0.8)
plt.scatter(df['xi'], df['f(xi)'], color='red', label='Эмпирическое распределение f(xi)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.2.3', fontsize=16)
plt.legend(fontsize=16)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   xi      61 non-null     float64
#  3   f(xi)   61 non-null     float64
# dtypes: float64(4)
# memory usage: 2.0 KB
# None

# %%
df = pd.read_csv("../test324.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
plt.plot(df['x'], df['f(x)'], linewidth=2,
         label='Теоретическое распределение смеси\nf(x) nu1=0.1, lambda1=1, mu1=0\nnu2=30, lambda2=1, mu2=0, p=0.5', alpha=0.8)
plt.scatter(df['xi'], df['f(xi)'], color='red', label='Эмпирическое распределение f(xi)', s=50)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.2.4', fontsize=16)
plt.legend(fontsize=16)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   xi      61 non-null     float64
#  3   f(xi)   61 non-null     float64
# dtypes: float64(4)
# memory usage: 2.0 KB
# None

# %%
df = pd.read_csv("../test3311.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
plt.plot(df['x'], df['f(x)'], linewidth=2,
         label='Теоретическое основное распределение f(x)\nnu=1, lambda=1, mu=0', alpha=0.8)
plt.plot(df['x'], df['fe(x)'], color='green', label='Теоретическое эмпиричиеское распределение\n'
        'построенное на выборке из основного f(x)', alpha=0.8)
plt.scatter(df['xi'], df['fe(xi)'], color='red', label='Эмпирическое распределение fe(xi)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.3.1.1', fontsize=16)
plt.legend(fontsize=14)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   fe(x)   61 non-null     float64
#  3   xi      61 non-null     float64
#  4   fe(xi)  61 non-null     float64
# dtypes: float64(5)
# memory usage: 2.5 KB
# None

# %%
df = pd.read_csv("../test3312.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
plt.plot(df['x'], df['f(x)'], linewidth=2,
         label='Теоретическое основное распределение f(x)\nnu=3, lambda=2, mu=10', alpha=0.8)
plt.plot(df['x'], df['fe(x)'], color='green', label='Теоретическое эмпиричиеское распределение\n'
        'построенное на выборке из основного f(x)', alpha=0.8)
plt.scatter(df['xi'], df['fe(xi)'], color='red', label='Эмпирическое распределение fe(xi)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.3.1.2', fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   fe(x)   61 non-null     float64
#  3   xi      61 non-null     float64
#  4   fe(xi)  61 non-null     float64
# dtypes: float64(5)
# memory usage: 2.5 KB
# None

# %%
df = pd.read_csv("../test3313.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
plt.plot(df['x'], df['f(x)'], linewidth=2,
         label='Теоретическое распределение смеси f(x)\nnu1=1, lambda1=1, mu1=0\n'
         'nu2=1, lambda2=2, mu2=0, p=0.5', alpha=0.8)
plt.plot(df['x'], df['fe(x)'], color='green', label='Теоретическое эмпиричиеское распределение\n'
        'построенное на выборке из смеси f(x)', alpha=0.8)
plt.scatter(df['xi'], df['fe(xi)'], color='red', label='Эмпирическое распределение fe(xi)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.3.1.3', fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   fe(x)   61 non-null     float64
#  3   xi      61 non-null     float64
#  4   fe(xi)  61 non-null     float64
# dtypes: float64(5)
# memory usage: 2.5 KB
# None

# %%
df = pd.read_csv("../test3314.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
plt.plot(df['x'], df['f(x)'], linewidth=2,
         label='Теоретическое распределение смеси f(x)\nnu1=1, lambda1=1, mu1=0\n'
         'nu2=3, lambda2=2, mu2=3, p=0.4', alpha=0.8)
plt.plot(df['x'], df['fe(x)'], color='green', label='Теоретическое эмпиричиеское распределение\n'
        'построенное на выборке из смеси f(x)', alpha=0.8)
plt.scatter(df['xi'], df['fe(xi)'], color='red', label='Эмпирическое распределение fe(xi)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.3.1.4', fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       61 non-null     float64
#  1   f(x)    61 non-null     float64
#  2   fe(x)   61 non-null     float64
#  3   xi      61 non-null     float64
#  4   fe(xi)  61 non-null     float64
# dtypes: float64(5)
# memory usage: 2.5 KB
# None

# %%
df = pd.read_csv("../test332.csv", sep=",")
print(df.info())
plt.figure(figsize=(16, 9))
plt.plot(df['x'], df['f(x)'], linewidth=2,
         label='Теоретическое основное распределение f(x)\nnu=1, lambda=1, mu=0\n', alpha=0.8)
plt.plot(df['x'], df['fe(x)'], color='green', label='Теоретическое эмпиричиеское распределение\n'
        'построенное на выборке из основного f(x)', alpha=0.8)
plt.plot(df['x'], df['fee(x)'], color='purple',
         label='Теоретическое эмпирическое распределение\nпостроенное на выборке из эмпирического fe(x)')
plt.scatter(df['xi'], df['fe(xi)'], color='yellow', label='Эмпирическое распределение fe(xi)', s=40)

plt.scatter(df['xie'], df['fee(xie)'], color='red', label='Эмпирическое распределение fee(xie)', s=40)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Тест 3.3.2', fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   x         61 non-null     float64
#  1   f(x)      61 non-null     float64
#  2   fe(x)     61 non-null     float64
#  3   xi        61 non-null     float64
#  4   fe(xi)    61 non-null     float64
#  5   fee(x)    61 non-null     float64
#  6   xie       61 non-null     float64
#  7   fee(xie)  61 non-null     float64
# dtypes: float64(8)
# memory usage: 3.9 KB
# None
